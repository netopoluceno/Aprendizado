# %%
import requests
import pandas as pd
import getpass
import json
import jwt
from datetime import datetime
import re

class PredictAPIClient():
    
    def __init__(self, email, password, project ='production'):
       self.email = email
       self.password = password
       self.token=''

       if project =='production':
            self.firebase_key = 'AIzaSyB2YzH6Vxj021oj1Prcdd8V-jpwUtbERMU'
            url_base = 'https://predict.dynamox.solutions'  
            self.psa_address = f'{url_base}/psa/v4'
            self.pra_address = f'{url_base}/pra/v4'
            self.public_key = '-----BEGINCERTIFICATE-----...-----ENDCERTIFICATE-----'
       
       elif project =='sandbox':
            self.firebase_key = 'AIzaSyCbgUaYoVbBUTy3RN2rJrfhmvdZW5G5f7k'
            url_base = 'https://sandbox.predict.dynamox.solutions'           
            self.psa_address = f'{url_base}/psa/v4'
            self.pra_address = f'{url_base}/pra/v4'
            self.public_key = '-----BEGINCERTIFICATE-----...-----ENDCERTIFICATE-----'
            
       elif project =='local':
            self.firebase_key = 'AIzaSyCbgUaYoVbBUTy3RN2rJrfhmvdZW5G5f7k'
            url_base = 'http://localhost'           
            self.psa_address = f'{url_base}:8080'
            self.pra_address = f'{url_base}:3003'
            self.public_key = '-----BEGINCERTIFICATE-----...-----ENDCERTIFICATE-----'

       else:
            url_base = []
            print('Connection problems, project name is incorrect!')
       self.login()

    def login(self):
            login_url = f'https://identitytoolkit.googleapis.com/v1/accounts:signInWithPassword?key={self.firebase_key}'
            self.login_data = {'email': self.email, 
                              'password': self.password,
                              'returnSecureToken': True}

            header = {'cache-control': 'no-cache',
                     'content-type': 'application/json',
                     'userAgent': 'Dyna-tools'}

            r = requests.post(login_url, data=json.dumps(self.login_data), headers=header)

            if r.status_code == 200:
               self.token = r.json()['idToken']
               print(f'Hello {email}')
            else:
               print(f'Connection problem getting measurements. HTTP Status Codes: {r.status_code}')
        
    def verify_token(self,token):
        decoded = jwt.JWT().decode(token, None, False)
        now = datetime.now().timestamp()
        exp = decoded.get("exp")
        diff = exp-now
        
        if diff < 300:
            print(f'Token expired, refreshing...')
            self.login()
            
            
email = 'edvaldo.neto@dynamox.net'
project = 'production'
password = getpass.getpass('Digite a senha: ')
api = PredictAPIClient(email, password, project)
# Out:
# Digite a senha: ········
# Hello edvaldo.neto@dynamox.net

# %%
#Patch Description

headers = {"Authorization": f"Bearer {api.token}",
           'cache-control': 'no-cache',
            'content-type' : 'application/json'}

data = pd.read_excel(r'C:\Users\edvaldo.neto\Desktop\992K.xlsx', sheet_name = 'patch_code')
assets = list(data['_id'])
code = list(data['code'])

#assets = ['64da82b01e950b457b5c3fc5']
#code = ['alterandoCode']

for i in range(len(assets)):
    
    payload_code = {"metadata":{"code":f"{code[i]}"}}
    
    api.verify_token(api.token)
    url = f'https://predict.dynamox.solutions/pra/v4/workspaces/{assets[i]}?version=3.22.2&client=predict-webapp'
    r = requests.patch(url, data = json.dumps(payload_code), headers = headers)
    print('PATCH' + '/' + 'ID: ' + str(assets[i]) + str(r))
    
print('Script Finalizado')
# Out:
# PATCH/ID: 664e3f58a1390843da2670e7<Response [200]>
# PATCH/ID: 664e3f806dbb8941400e00e2<Response [200]>
# PATCH/ID: 664e3f805ac1946c12fcece8<Response [200]>
# PATCH/ID: 664e3f804ccee00d8c76cb65<Response [200]>
# PATCH/ID: 664e3f8044345468a0c92df8<Response [200]>
# PATCH/ID: 664e3f8019a6b060a73c6985<Response [200]>
# PATCH/ID: 664e3f81dfd144530e67afce<Response [200]>
# PATCH/ID: 664e3f5881d36cc7cf3c8115<Response [200]>
# PATCH/ID: 664e3f815e09fc7650231e57<Response [200]>
# PATCH/ID: 664e3f81bb78dc078e1277e2<Response [200]>
# PATCH/ID: 664e3f814ccee0dd8076cb66<Response [200]>
# PATCH/ID: 664e3f81a13908c4b42670eb<Response [200]>
# PATCH/ID: 664e3f82dfd14441b667afcf<Response [200]>
# PATCH/ID: 664e3f8381c6a3061ccfb91f<Response [200]>
# PATCH/ID: 664e3f5832e1df74a09ab2ad<Response [200]>
# PATCH/ID: 664e3f586dbb890fc50e00df<Response [200]>
# PATCH/ID: 664e3f8381c6a31986cfb920<Response [200]>
# PATCH/ID: 664e3f836dbb8945c90e00e3<Response [200]>
# PATCH/ID: 664e3f8381d36c7e913c811c<Response [200]>
# PATCH/ID: 664e3f83f770ce79b0f29600<Response [200]>
# PATCH/ID: 664e3f844ccee008a876cb67<Response [200]>
# PATCH/ID: 664e3f844ccee01e8076cb68<Response [200]>
# PATCH/ID: 664e3f84a1390856252670ec<Response [200]>
# PATCH/ID: 664e3f844434543cf9c92df9<Response [200]>
# PATCH/ID: 664e3f58443454ec98c92df4<Response [200]>
# PATCH/ID: 664e3f84e434ef3cae68f5d8<Response [200]>
# PATCH/ID: 664e3f85e434ef292e68f5d9<Response [200]>
# PATCH/ID: 664e3f85a13908061a2670ed<Response [200]>
# PATCH/ID: 664e3f8581d36cfcdc3c811d<Response [200]>
# PATCH/ID: 664e3f8581d36c38a53c811e<Response [200]>
# PATCH/ID: 664e3f854434546848c92dfa<Response [200]>
# PATCH/ID: 664e3f864434540e0ac92dfb<Response [200]>
# PATCH/ID: 664e3f86dfd1441df367afd0<Response [200]>
# PATCH/ID: 664e3f86bb78dc3eef1277e3<Response [200]>
# PATCH/ID: 664e3f866451d0655f859012<Response [200]>
# PATCH/ID: 664e3f5a5e09fc5023231e4e<Response [200]>
# PATCH/ID: 664e3f876451d09a2d859013<Response [200]>
# PATCH/ID: 664e3f8732e1dffdb29ab2b1<Response [200]>
# PATCH/ID: 664e3f875e09fc69c3231e58<Response [200]>
# PATCH/ID: 664e3f87f770ceca22f29601<Response [200]>
# PATCH/ID: 664e3f5a5e09fc9a59231e4f<Response [200]>
# PATCH/ID: 664e3f884434542eccc92dfc<Response [200]>
# PATCH/ID: 664e3f885e09fc8426231e59<Response [200]>
# PATCH/ID: 664e3f88bb78dc29221277e4<Response [200]>
# PATCH/ID: 664e3f885e09fc23fd231e5a<Response [200]>
# PATCH/ID: 664e3f884ccee0e0c176cb69<Response [200]>
# PATCH/ID: 664e3f896dbb897f480e00e4<Response [200]>
# PATCH/ID: 664e3f89a1390857912670ee<Response [200]>
# PATCH/ID: 664e3f896451d062ce859014<Response [200]>
# PATCH/ID: 664e3f8abb78dc73631277e5<Response [200]>
# PATCH/ID: 664e3f894434544ab3c92dfd<Response [200]>
# PATCH/ID: 664e3f8a5e09fc80b4231e5b<Response [200]>
# PATCH/ID: 664e3f8aa1390806dc2670ef<Response [200]>
# PATCH/ID: 664e3f8af770cec6a0f29602<Response [200]>
# PATCH/ID: 664e3f8bdfd1449cca67afd1<Response [200]>
# PATCH/ID: 664e3f8b81c6a31ef4cfb921<Response [200]>
# PATCH/ID: 664e3f8b81c6a314e9cfb922<Response [200]>
# PATCH/ID: 664e3f8ba1390835652670f0<Response [200]>
# PATCH/ID: 664e3f8c32e1dfc6a99ab2b2<Response [200]>
# PATCH/ID: 664e3f5a5ac194d268fcece4<Response [200]>
# PATCH/ID: 664e3f8c5ac194857bfcece9<Response [200]>
# PATCH/ID: 664e3f8c81c6a30941cfb923<Response [200]>
# PATCH/ID: 664e3f8cbb78dc68ad1277e6<Response [200]>
# PATCH/ID: 664e3f8ca139080c442670f1<Response [200]>
# PATCH/ID: 664e3f8d4434549926c92dfe<Response [200]>
# PATCH/ID: 664e3f8d5e09fca869231e5c<Response [200]>
# PATCH/ID: 664e3f8ef770ce07d8f29603<Response [200]>
# PATCH/ID: 664e3f8edfd144643067afd2<Response [200]>
# PATCH/ID: 664e3f5adfd144dad067afc9<Response [200]>
# PATCH/ID: 664e3f8ebb78dc0b8e1277e7<Response [200]>
# PATCH/ID: 664e3f8e4ccee033c176cb6a<Response [200]>
# PATCH/ID: 664e3f8ea13908f5d22670f2<Response [200]>
# PATCH/ID: 664e3f8f5e09fc039a231e5d<Response [200]>
# PATCH/ID: 664e3f8f32e1df4dd09ab2b3<Response [200]>
# PATCH/ID: 664e3f8f6451d0469c859015<Response [200]>
# PATCH/ID: 664e3f8fdfd14453e467afd3<Response [200]>
# PATCH/ID: 664e3f8f5ac1944695fcecea<Response [200]>
# PATCH/ID: 664e3f5a6451d0548b85900e<Response [200]>
# PATCH/ID: 664e3f9081c6a36f0ccfb924<Response [200]>
# PATCH/ID: 664e3f90a139082a462670f3<Response [200]>
# PATCH/ID: 664e3f9019a6b0dffc3c6986<Response [200]>
# PATCH/ID: 664e3f904ccee0944376cb6b<Response [200]>
# PATCH/ID: 664e3f9181d36c02ac3c811f<Response [200]>
# PATCH/ID: 664e3f91e434efdfe668f5da<Response [200]>
# PATCH/ID: 664e3f91e434ef730668f5db<Response [200]>
# PATCH/ID: 664e3f9181c6a36e56cfb925<Response [200]>
# PATCH/ID: 664e3f5b32e1df92ce9ab2ae<Response [200]>
# PATCH/ID: 664e3f91443454e181c92dff<Response [200]>
# PATCH/ID: 664e3f92bb78dc01e41277e8<Response [200]>
# PATCH/ID: 664e3f925ac1944d9dfceceb<Response [200]>
# PATCH/ID: 664e3f926451d01c92859016<Response [200]>
# PATCH/ID: 664e3f5bf770ce43a0f295f9<Response [200]>
# PATCH/ID: 664e3f92e434ef1b7568f5dc<Response [200]>
# PATCH/ID: 664e3f9381d36c35d43c8120<Response [200]>
# PATCH/ID: 664e3f9381d36ca2303c8121<Response [200]>
# PATCH/ID: 664e3f9481c6a37ee6cfb926<Response [200]>
# PATCH/ID: 664e3f945e09fc0ac7231e5e<Response [200]>
# PATCH/ID: 664e3f9481d36cca173c8122<Response [200]>
# PATCH/ID: 664e3f94443454c902c92e00<Response [200]>
# PATCH/ID: 664e3f9432e1df95959ab2b4<Response [200]>
# PATCH/ID: 664e3f9581d36c14b43c8123<Response [200]>
# PATCH/ID: 664e3f956dbb895ac50e00e5<Response [200]>
# PATCH/ID: 664e3f956451d0fa86859017<Response [200]>
# PATCH/ID: 664e3f95e434efb9ef68f5dd<Response [200]>
# PATCH/ID: 664e3f955ac194798afcecec<Response [200]>
# PATCH/ID: 664e3f966dbb897b600e00e6<Response [200]>
# PATCH/ID: 664e3f9681c6a398c6cfb927<Response [200]>
# PATCH/ID: 664e3f9619a6b0048f3c6987<Response [200]>
# PATCH/ID: 664e3f5b5ac194177cfcece5<Response [200]>
# PATCH/ID: 664e3f9781c6a32924cfb928<Response [200]>
# PATCH/ID: 664e3f96a13908fa002670f4<Response [200]>
# PATCH/ID: 664e3f97bb78dcecd91277e9<Response [200]>
# PATCH/ID: 664e3f976451d02307859018<Response [200]>
# PATCH/ID: 664e3f98bb78dc61571277ea<Response [200]>
# PATCH/ID: 664e3f98e434ef1d9768f5de<Response [200]>
# PATCH/ID: 664e3f985ac194d0e6fceced<Response [200]>
# PATCH/ID: 664e3f99bb78dc68381277eb<Response [200]>
# PATCH/ID: 664e3f99a139081f6d2670f5<Response [200]>
# PATCH/ID: 664e3f5cbb78dc287f1277de<Response [200]>
# PATCH/ID: 664e3f994434540eb1c92e01<Response [200]>
# PATCH/ID: 664e3f9aa13908068e2670f6<Response [200]>
# PATCH/ID: 664e3f9abb78dc65871277ec<Response [200]>
# PATCH/ID: 664e3f9af770ce2570f29604<Response [200]>
# PATCH/ID: 664e3f9a5ac1941b55fcecee<Response [200]>
# PATCH/ID: 664e3f9b81d36c033a3c8124<Response [200]>
# PATCH/ID: 664e3f9b19a6b0d1673c6988<Response [200]>
# PATCH/ID: 664e3f9b443454a0a0c92e02<Response [200]>
# PATCH/ID: 664e3f9cbb78dc00a41277ed<Response [200]>
# PATCH/ID: 664e3f9cbb78dc602c1277ee<Response [200]>
# PATCH/ID: 664e3f9c81d36c74ce3c8125<Response [200]>
# PATCH/ID: 664e3f5cf770ced484f295fa<Response [200]>
# PATCH/ID: 664e3f9c4434543773c92e03<Response [200]>
# PATCH/ID: 664e3f9d443454e70ac92e04<Response [200]>
# PATCH/ID: 664e3f9d6dbb89e5ae0e00e7<Response [200]>
# PATCH/ID: 664e3f9df770ce9c2ef29605<Response [200]>
# PATCH/ID: 664e3f9d81c6a33a00cfb929<Response [200]>
# PATCH/ID: 664e3f9d443454a016c92e05<Response [200]>
# PATCH/ID: 664e3f5c81d36c75773c8116<Response [200]>
# PATCH/ID: 664e3f9ee434ef01f768f5df<Response [200]>
# PATCH/ID: 664e3f9e81d36c15853c8126<Response [200]>
# PATCH/ID: 664e3f9e6dbb8936c40e00e8<Response [200]>
# PATCH/ID: 664e3f9e4ccee01fac76cb6c<Response [200]>
# PATCH/ID: 664e3f9e6451d09daf859019<Response [200]>
# PATCH/ID: 664e3f9fa13908d3892670f7<Response [200]>
# PATCH/ID: 664e3f5c5e09fce1f6231e50<Response [200]>
# PATCH/ID: 664e3f5d6451d01a7e85900f<Response [200]>
# PATCH/ID: 664e3f9f81c6a30b60cfb92a<Response [200]>
# PATCH/ID: 664e3f9f5e09fc4d96231e5f<Response [200]>
# PATCH/ID: 664e3f9f19a6b07adf3c6989<Response [200]>
# PATCH/ID: 664e3f9ff770ce2d22f29606<Response [200]>
# PATCH/ID: 664e3fa04ccee02f3276cb6d<Response [200]>
# PATCH/ID: 664e3fa0bb78dc7eee1277ef<Response [200]>
# PATCH/ID: 664e3fa0f770ceb7a8f29607<Response [200]>
# PATCH/ID: 664e3fa132e1dfe8d69ab2b5<Response [200]>
# PATCH/ID: 664e3f5d44345479cbc92df5<Response [200]>
# PATCH/ID: 664e3fa14ccee06dc476cb6e<Response [200]>
# PATCH/ID: 664e3fa232e1dfed689ab2b6<Response [200]>
# PATCH/ID: 664e3fa181d36c1cfb3c8127<Response [200]>
# PATCH/ID: 664e3fa2bb78dc20671277f0<Response [200]>
# PATCH/ID: 664e3fa219a6b001c03c698a<Response [200]>
# PATCH/ID: 664e3fa24ccee0da9a76cb6f<Response [200]>
# PATCH/ID: 664e3fa36451d0dfcc85901a<Response [200]>
# PATCH/ID: 664e3fa34ccee067dd76cb70<Response [200]>
# PATCH/ID: 664e3fa3dfd14440e267afd4<Response [200]>
# PATCH/ID: 664e3fa3443454883bc92e06<Response [200]>
# PATCH/ID: 664e3f5e5e09fc2e51231e51<Response [200]>
# PATCH/ID: 664e3fa4f770ceb591f29608<Response [200]>
# PATCH/ID: 664e3fa432e1dfb6449ab2b7<Response [200]>
# PATCH/ID: 664e3fa45ac19422f8fcecef<Response [200]>
# PATCH/ID: 664e3fa45e09fcded2231e60<Response [200]>
# PATCH/ID: 664e3f5d32e1df89799ab2af<Response [200]>
# PATCH/ID: 664e3fa55ac1949e0efcecf0<Response [200]>
# PATCH/ID: 664e3fa55ac1944891fcecf1<Response [200]>
# PATCH/ID: 664e3fa581c6a38618cfb92b<Response [200]>
# PATCH/ID: 664e3fa581d36cce4a3c8128<Response [200]>
# PATCH/ID: 664e3fa581d36ceffb3c8129<Response [200]>
# PATCH/ID: 664e3fa681c6a3279fcfb92c<Response [200]>
# PATCH/ID: 664e3fa65e09fc8542231e61<Response [200]>
# PATCH/ID: 664e3fa6a1390800102670f8<Response [200]>
# PATCH/ID: 664e3fa732e1df4b459ab2b8<Response [200]>
# PATCH/ID: 664e3fa6dfd1441e8a67afd5<Response [200]>
# PATCH/ID: 664e3fa75ac19467b5fcecf2<Response [200]>
# PATCH/ID: 664e3fa74ccee07c0776cb71<Response [200]>
# PATCH/ID: 664e3fa75e09fc0af9231e62<Response [200]>
# PATCH/ID: 664e3fa84ccee0b62b76cb72<Response [200]>
# PATCH/ID: 664e3fa85ac194819afcecf3<Response [200]>
# PATCH/ID: 664e3fa84434549a30c92e07<Response [200]>
# PATCH/ID: 664e3fa819a6b0fda33c698b<Response [200]>
# PATCH/ID: 664e3fa881d36cdd023c812a<Response [200]>
# PATCH/ID: 664e3f5ebb78dc22dc1277df<Response [200]>
# PATCH/ID: 664e3fa96dbb89503f0e00e9<Response [200]>
# PATCH/ID: 664e3fa9a139083bdb2670f9<Response [200]>
# PATCH/ID: 664e3fa9dfd14421ac67afd6<Response [200]>
# PATCH/ID: 664e3fa94434543a57c92e08<Response [200]>
# PATCH/ID: 664e3fa944345470bac92e09<Response [200]>
# PATCH/ID: 664e3faa19a6b041683c698c<Response [200]>
# PATCH/ID: 664e3faa32e1df16079ab2b9<Response [200]>
# PATCH/ID: 664e3fab443454ddd1c92e0a<Response [200]>
# PATCH/ID: 664e3f5e5e09fc5044231e52<Response [200]>
# PATCH/ID: 664e3fab81c6a31a23cfb92d<Response [200]>
# PATCH/ID: 664e3fabf770ceb71ef29609<Response [200]>
# PATCH/ID: 664e3fab81d36cacf53c812b<Response [200]>
# PATCH/ID: 664e3fac5ac1945ccbfcecf4<Response [200]>
# PATCH/ID: 664e3facf770ce4582f2960a<Response [200]>
# PATCH/ID: 664e3fac5ac1940f29fcecf5<Response [200]>
# PATCH/ID: 664e3facdfd14467b667afd7<Response [200]>
# PATCH/ID: 664e3fac5ac19498f7fcecf6<Response [200]>
# PATCH/ID: 664e3f5e4434549d9ec92df6<Response [200]>
# PATCH/ID: 664e3fad6dbb89115b0e00ea<Response [200]>
# PATCH/ID: 664e3faddfd144e5a267afd8<Response [200]>
# PATCH/ID: 664e3fad81d36ccb913c812c<Response [200]>
# PATCH/ID: 664e3fad44345438dfc92e0b<Response [200]>
# PATCH/ID: 664e3fae443454155dc92e0c<Response [200]>
# PATCH/ID: 664e3fae81c6a3cfa8cfb92e<Response [200]>
# PATCH/ID: 664e3faf6dbb89683e0e00eb<Response [200]>
# PATCH/ID: 664e3fafe434ef4e5368f5e0<Response [200]>
# PATCH/ID: 664e3f5fbb78dccf721277e0<Response [200]>
# PATCH/ID: 664e3faf443454f110c92e0d<Response [200]>
# PATCH/ID: 664e3fafdfd144ba9067afd9<Response [200]>
# PATCH/ID: 664e3fb081d36c317e3c812d<Response [200]>
# PATCH/ID: 664e3fb081c6a38a7acfb92f<Response [200]>
# PATCH/ID: 664e3f5f81d36c5d713c8117<Response [200]>
# PATCH/ID: 664e3fb0bb78dc06f61277f1<Response [200]>
# PATCH/ID: 664e3fb0a13908867a2670fa<Response [200]>
# PATCH/ID: 664e3fb1bb78dc8cc31277f2<Response [200]>
# PATCH/ID: 664e3fb15e09fc6c3a231e63<Response [200]>
# PATCH/ID: 664e3fb14ccee0ee0c76cb73<Response [200]>
# PATCH/ID: 664e3fb1dfd1442fa667afda<Response [200]>
# PATCH/ID: 664e3fb15e09fc277c231e64<Response [200]>
# PATCH/ID: 664e3fb26451d0385585901b<Response [200]>
# PATCH/ID: 664e3fb26451d0c89585901c<Response [200]>
# PATCH/ID: 664e3fb24ccee0417876cb74<Response [200]>
# PATCH/ID: 664e3fb281c6a3c035cfb930<Response [200]>
# PATCH/ID: 664e3fb36451d0a72585901d<Response [200]>
# PATCH/ID: 664e3fb381d36c5b2a3c812e<Response [200]>
# PATCH/ID: 664e3fb3443454c1c4c92e0e<Response [200]>
# PATCH/ID: 664e3fb3f770ce3570f2960b<Response [200]>
# PATCH/ID: 664e3fb4dfd1449d8c67afdb<Response [200]>
# PATCH/ID: 664e3f5f443454d85dc92df7<Response [200]>
# PATCH/ID: 664e3fb481c6a31d3bcfb931<Response [200]>
# PATCH/ID: 664e3fb4f770cefdb3f2960c<Response [200]>
# PATCH/ID: 664e3fb44ccee04ddb76cb75<Response [200]>
# PATCH/ID: 664e3f5fbb78dc1b981277e1<Response [200]>
# PATCH/ID: 664e3fb55ac1946f14fcecf7<Response [200]>
# PATCH/ID: 664e3fb5a139084dba2670fb<Response [200]>
# PATCH/ID: 664e3fb55ac194162ffcecf8<Response [200]>
# PATCH/ID: 664e3fb54ccee0591a76cb76<Response [200]>
# PATCH/ID: 664e3fb55ac1943aabfcecf9<Response [200]>
# PATCH/ID: 664e3fb6a139081f852670fc<Response [200]>
# PATCH/ID: 664e3f5fa1390862902670e8<Response [200]>
# PATCH/ID: 664e3fb66451d0401c85901e<Response [200]>
# PATCH/ID: 664e3fb6bb78dc578c1277f3<Response [200]>
# PATCH/ID: 664e3fb732e1dffe669ab2ba<Response [200]>
# PATCH/ID: 664e3fb65ac19411ebfcecfa<Response [200]>
# PATCH/ID: 664e3fb7e434efb68568f5e1<Response [200]>
# PATCH/ID: 664e3fb7a1390893012670fd<Response [200]>
# PATCH/ID: 664e3fb781c6a3f61bcfb932<Response [200]>
# PATCH/ID: 664e3fb732e1df71dd9ab2bb<Response [200]>
# PATCH/ID: 664e3fb84ccee0475b76cb77<Response [200]>
# PATCH/ID: 664e3fb8f770ce2afff2960d<Response [200]>
# PATCH/ID: 664e3fb86451d06da485901f<Response [200]>
# PATCH/ID: 664e3f60dfd144312967afca<Response [200]>
# PATCH/ID: 664e3fb9bb78dc1d1e1277f4<Response [200]>
# PATCH/ID: 664e3fb96451d07ded859020<Response [200]>
# PATCH/ID: 664e3fb981c6a3c8e5cfb933<Response [200]>
# PATCH/ID: 664e3fb95e09fc3c2e231e65<Response [200]>
# PATCH/ID: 664e3fba81c6a3b647cfb934<Response [200]>
# PATCH/ID: 664e3fbaa139085d552670fe<Response [200]>
# PATCH/ID: 664e3f604ccee0308776cb64<Response [200]>
# PATCH/ID: 664e3fba6dbb899b180e00ec<Response [200]>
# PATCH/ID: 664e3fbabb78dc4f521277f5<Response [200]>
# PATCH/ID: 664e3fbb5ac19423e5fcecfb<Response [200]>
# PATCH/ID: 664e3fbb81d36cb8753c812f<Response [200]>
# PATCH/ID: 664e3fbb81c6a3c7f2cfb935<Response [200]>
# PATCH/ID: 664e3fbb81c6a30fc6cfb936<Response [200]>
# PATCH/ID: 664e3f60f770ce4ae6f295fb<Response [200]>
# PATCH/ID: 664e3f605e09fcb069231e53<Response [200]>
# PATCH/ID: 664e3fbb5ac1943b70fcecfc<Response [200]>
# PATCH/ID: 664e3fbc5e09fc03ae231e66<Response [200]>
# PATCH/ID: 664e3fbc4434543accc92e0f<Response [200]>
# PATCH/ID: 664e3fbc5ac19401fcfcecfd<Response [200]>
# PATCH/ID: 664e3fbc5ac19405aefcecfe<Response [200]>
# PATCH/ID: 664e3fbdbb78dc0c161277f6<Response [200]>
# PATCH/ID: 664e3fbd6dbb892e6d0e00ed<Response [200]>
# PATCH/ID: 664e3fbdf770cef135f2960e<Response [200]>
# PATCH/ID: 664e3f605ac194adaafcece6<Response [200]>
# PATCH/ID: 664e3fbdbb78dce3c41277f7<Response [200]>
# PATCH/ID: 664e3fbe81c6a36bbfcfb937<Response [200]>
# PATCH/ID: 664e3fbe4ccee03eb376cb78<Response [200]>
# PATCH/ID: 664e3fbe5ac194b2f1fcecff<Response [200]>
# PATCH/ID: 664e3fbf4ccee0b38776cb79<Response [200]>
# PATCH/ID: 664e3fbf32e1dfef9b9ab2bc<Response [200]>
# PATCH/ID: 664e3fbfa13908cb1f2670ff<Response [200]>
# PATCH/ID: 664e3fbfdfd144e74567afdc<Response [200]>
# PATCH/ID: 664e3fbfbb78dcb2e11277f8<Response [200]>
# PATCH/ID: 664e3fc019a6b026623c698d<Response [200]>
# PATCH/ID: 664e3f61a1390871192670e9<Response [200]>
# PATCH/ID: 664e3fc06451d026b8859021<Response [200]>
# PATCH/ID: 664e3fc0dfd144014c67afdd<Response [200]>
# PATCH/ID: 664e3fc0f770ce07aaf2960f<Response [200]>
# PATCH/ID: 664e3fc181d36c078d3c8130<Response [200]>
# PATCH/ID: 664e3f6181d36c64293c8118<Response [200]>
# PATCH/ID: 664e3fc14ccee046b076cb7a<Response [200]>
# PATCH/ID: 664e3fc1f770ce264cf29610<Response [200]>
# PATCH/ID: 664e3fc1bb78dcf2491277f9<Response [200]>
# PATCH/ID: 664e3fc132e1df1fe99ab2bd<Response [200]>
# PATCH/ID: 664e3fc281d36c0e213c8131<Response [200]>
# PATCH/ID: 664e3fc25ac194e903fced00<Response [200]>
# PATCH/ID: 664e3fc25ac194606afced01<Response [200]>
# PATCH/ID: 664e3fc25ac1942feafced02<Response [200]>
# PATCH/ID: 664e3fc332e1df561e9ab2be<Response [200]>
# PATCH/ID: 664e3fc319a6b0734e3c698e<Response [200]>
# PATCH/ID: 664e3fc3e434efb6f768f5e2<Response [200]>
# PATCH/ID: 664e3fc3a139083d45267100<Response [200]>
# PATCH/ID: 664e3fc46dbb893e1a0e00ee<Response [200]>
# PATCH/ID: 664e3fc4f770ce1c5cf29611<Response [200]>
# PATCH/ID: 664e3fc419a6b0017e3c698f<Response [200]>
# PATCH/ID: 664e3fc5bb78dccedf1277fa<Response [200]>
# PATCH/ID: 664e3fc5a139083f18267101<Response [200]>
# PATCH/ID: 664e3fc55e09fc9458231e67<Response [200]>
# PATCH/ID: 664e3f6181d36c1c593c8119<Response [200]>
# PATCH/ID: 664e3fc64ccee0e8f576cb7b<Response [200]>
# PATCH/ID: 664e3fc64ccee001cb76cb7c<Response [200]>
# PATCH/ID: 664e3fc6e434ef580b68f5e3<Response [200]>
# PATCH/ID: 664e3fc644345408afc92e10<Response [200]>
# PATCH/ID: 664e3fc64ccee0365d76cb7d<Response [200]>
# PATCH/ID: 664e3fc732e1df70d79ab2bf<Response [200]>
# PATCH/ID: 664e3fc781c6a3314fcfb938<Response [200]>
# PATCH/ID: 664e3fc76dbb8948db0e00ef<Response [200]>
# PATCH/ID: 664e3f62f770ce84f8f295fc<Response [200]>
# PATCH/ID: 664e3fc75ac19474d5fced03<Response [200]>
# PATCH/ID: 664e3fc7dfd14459f767afde<Response [200]>
# PATCH/ID: 664e3fc8bb78dceb641277fb<Response [200]>
# PATCH/ID: 664e3fc8a13908c338267102<Response [200]>
# PATCH/ID: 664e3fc8443454ad29c92e11<Response [200]>
# PATCH/ID: 664e3fc819a6b0301d3c6990<Response [200]>
# PATCH/ID: 664e3fc8f770ce8944f29612<Response [200]>
# PATCH/ID: 664e3fc96dbb89b25d0e00f0<Response [200]>
# PATCH/ID: 664e3f6132e1df6bfd9ab2b0<Response [200]>
# PATCH/ID: 664e3fc96dbb8962b70e00f1<Response [200]>
# PATCH/ID: 664e3fc9e434efc68668f5e4<Response [200]>
# PATCH/ID: 664e3fc95ac1944249fced04<Response [200]>
# PATCH/ID: 664e3fcae434efcc8368f5e5<Response [200]>
# PATCH/ID: 664e3fca19a6b056f13c6991<Response [200]>
# PATCH/ID: 664e3fca6451d059ac859022<Response [200]>
# PATCH/ID: 664e3fca4ccee0429476cb7e<Response [200]>
# PATCH/ID: 664e3fcaf770ce28aef29613<Response [200]>
# PATCH/ID: 664e3f626dbb89102b0e00e1<Response [200]>
# PATCH/ID: 664e3fcb32e1df271f9ab2c0<Response [200]>
# PATCH/ID: 664e3fcbe434eff3d568f5e6<Response [200]>
# PATCH/ID: 664e3fcb44345498e5c92e12<Response [200]>
# PATCH/ID: 664e3fcce434ef3d2068f5e7<Response [200]>
# PATCH/ID: 664e3f6281c6a33fd3cfb91c<Response [200]>
# PATCH/ID: 664e3fcbdfd144748767afdf<Response [200]>
# PATCH/ID: 664e3fccdfd144533567afe0<Response [200]>
# PATCH/ID: 664e3fcddfd1443b6667afe1<Response [200]>
# PATCH/ID: 664e3fcd443454d274c92e13<Response [200]>
# PATCH/ID: 664e3fcd4434545692c92e14<Response [200]>
# PATCH/ID: 664e3fcd4434545ae1c92e15<Response [200]>
# PATCH/ID: 664e3fce6dbb8950740e00f2<Response [200]>
# PATCH/ID: 664e3fce19a6b018413c6992<Response [200]>
# PATCH/ID: 664e3fce81c6a330bfcfb939<Response [200]>
# PATCH/ID: 664e3fce81d36caa663c8132<Response [200]>
# PATCH/ID: 664e3fce19a6b0cbb33c6993<Response [200]>
# PATCH/ID: 664e3fcf81d36c72443c8133<Response [200]>
# PATCH/ID: 664e3fcf81d36cd9b43c8134<Response [200]>
# PATCH/ID: 664e3fcfbb78dc511b1277fc<Response [200]>
# PATCH/ID: 664e3fcfdfd144ecb367afe2<Response [200]>
# PATCH/ID: 664e3fcf4ccee0804776cb7f<Response [200]>
# PATCH/ID: 664e3f626451d0479f859010<Response [200]>
# PATCH/ID: 664e3fd05ac194236dfced05<Response [200]>
# PATCH/ID: 664e3fd0e434efa33e68f5e8<Response [200]>
# PATCH/ID: 664e3fd0a13908a219267103<Response [200]>
# PATCH/ID: 664e3f635ac19479e4fcece7<Response [200]>
# PATCH/ID: 664e3fd1bb78dc0ae41277fd<Response [200]>
# PATCH/ID: 664e3fd181c6a30befcfb93a<Response [200]>
# PATCH/ID: 664e3fd119a6b0d7303c6994<Response [200]>
# PATCH/ID: 664e3fd1bb78dc53481277fe<Response [200]>
# PATCH/ID: 664e3fd16451d0b7ca859023<Response [200]>
# PATCH/ID: 664e3fd2dfd1445ac867afe3<Response [200]>
# PATCH/ID: 664e3f6381c6a379b2cfb91d<Response [200]>
# PATCH/ID: 664e3fd2f770ce1c25f29614<Response [200]>
# PATCH/ID: 664e3fd25ac194448bfced06<Response [200]>
# PATCH/ID: 664e3fd281d36c5f363c8135<Response [200]>
# PATCH/ID: 664e3fd2a13908be0e267104<Response [200]>
# PATCH/ID: 664e3fd319a6b06aa03c6995<Response [200]>
# PATCH/ID: 664e3fd3a139087308267105<Response [200]>
# PATCH/ID: 664e3fd4443454811ec92e16<Response [200]>
# PATCH/ID: 664e3fd419a6b005bb3c6996<Response [200]>
# PATCH/ID: 664e3fd4bb78dc62de1277ff<Response [200]>
# PATCH/ID: 664e3fd4e434ef565f68f5e9<Response [200]>
# PATCH/ID: 664e3fd45e09fc84fa231e68<Response [200]>
# PATCH/ID: 664e3f6381d36c5be13c811a<Response [200]>
# PATCH/ID: 664e3fd581c6a32326cfb93b<Response [200]>
# PATCH/ID: 664e3fd55ac1941de4fced07<Response [200]>
# PATCH/ID: 664e3fd54ccee07dc476cb80<Response [200]>
# PATCH/ID: 664e3fd5a13908419a267106<Response [200]>
# PATCH/ID: 664e3fd66dbb89b01b0e00f3<Response [200]>
# PATCH/ID: 664e3fd64ccee07c9476cb81<Response [200]>
# PATCH/ID: 664e3f64a1390868662670ea<Response [200]>
# PATCH/ID: 664e3fd64ccee05abb76cb82<Response [200]>
# PATCH/ID: 664e3fd6bb78dc31d4127800<Response [200]>
# PATCH/ID: 664e3fd64ccee0452e76cb83<Response [200]>
# PATCH/ID: 664e3fd74ccee0a5cb76cb84<Response [200]>
# PATCH/ID: 664e3fd76451d06cbf859024<Response [200]>
# PATCH/ID: 664e3fd7bb78dcb145127801<Response [200]>
# PATCH/ID: 664e3f636451d09149859011<Response [200]>
# PATCH/ID: 664e3f6419a6b08ac73c6983<Response [200]>
# PATCH/ID: 664e3fd781d36c0bd93c8136<Response [200]>
# PATCH/ID: 664e3fd881d36c68cc3c8137<Response [200]>
# PATCH/ID: 664e3fd819a6b048fe3c6997<Response [200]>
# PATCH/ID: 664e3fd8443454e68cc92e17<Response [200]>
# PATCH/ID: 664e3fd832e1dfb0e29ab2c1<Response [200]>
# PATCH/ID: 664e3fd85ac194ba38fced08<Response [200]>
# PATCH/ID: 664e3fd9f770ce9df4f29615<Response [200]>
# PATCH/ID: 664e3fd96dbb89797c0e00f4<Response [200]>
# PATCH/ID: 664e3f64dfd144641c67afcb<Response [200]>
# PATCH/ID: 664e3fd95e09fc46e8231e69<Response [200]>
# PATCH/ID: 664e3fd95ac194862ffced09<Response [200]>
# PATCH/ID: 664e3fd96451d079a4859025<Response [200]>
# PATCH/ID: 664e3fdabb78dc2dd4127802<Response [200]>
# PATCH/ID: 664e3fda6451d0be35859026<Response [200]>
# PATCH/ID: 664e3fdae434ef24e368f5ea<Response [200]>
# PATCH/ID: 664e3fda5e09fccf19231e6a<Response [200]>
# PATCH/ID: 664e3fdb4ccee02e4176cb85<Response [200]>
# PATCH/ID: 664e3fdbbb78dcc8fd127803<Response [200]>
# PATCH/ID: 664e3fdb5ac194dc58fced0a<Response [200]>
# PATCH/ID: 664e3f64dfd1447d0067afcc<Response [200]>
# PATCH/ID: 664e3fdbdfd1441fa467afe4<Response [200]>
# PATCH/ID: 664e3fdc19a6b050ae3c6998<Response [200]>
# PATCH/ID: 664e3fdc443454c044c92e18<Response [200]>
# PATCH/ID: 664e3fdca13908b9a9267107<Response [200]>
# PATCH/ID: 664e3f645e09fc860b231e54<Response [200]>
# PATCH/ID: 664e3fdca139084a57267108<Response [200]>
# PATCH/ID: 664e3fdc4ccee0379076cb86<Response [200]>
# PATCH/ID: 664e3fdde434ef6ab368f5eb<Response [200]>
# PATCH/ID: 664e3fddf770ce4e89f29616<Response [200]>
# PATCH/ID: 664e3fdd4ccee03bb576cb87<Response [200]>
# PATCH/ID: 664e3fdd4434545ce2c92e19<Response [200]>
# PATCH/ID: 664e3fdd5e09fcd21b231e6b<Response [200]>
# PATCH/ID: 664e3fdea13908b18f267109<Response [200]>
# PATCH/ID: 664e3fdf6451d0d76a859028<Response [200]>
# PATCH/ID: 664e3fde4ccee048b676cb88<Response [200]>
# PATCH/ID: 664e3fde6451d088dc859027<Response [200]>
# PATCH/ID: 664e3fde5ac1948541fced0b<Response [200]>
# PATCH/ID: 664e3fdf81d36c9a113c8138<Response [200]>
# PATCH/ID: 664e3fdf32e1df9b1f9ab2c2<Response [200]>
# PATCH/ID: 664e3fe032e1df2ce69ab2c3<Response [200]>
# PATCH/ID: 664e3fe05ac1942216fced0c<Response [200]>
# PATCH/ID: 664e3fe0bb78dc39b5127804<Response [200]>
# PATCH/ID: 664e3fe081d36c4fe43c8139<Response [200]>
# PATCH/ID: 664e3f6519a6b021ff3c6984<Response [200]>
# PATCH/ID: 664e3fe06dbb8912680e00f5<Response [200]>
# PATCH/ID: 664e3fe144345448e9c92e1a<Response [200]>
# PATCH/ID: 664e3fe1e434efa6c068f5ec<Response [200]>
# PATCH/ID: 664e3fe181d36cbb3c3c813a<Response [200]>
# PATCH/ID: 664e3fe2bb78dcc28e127805<Response [200]>
# PATCH/ID: 664e3fe16dbb8913040e00f6<Response [200]>
# PATCH/ID: 664e3fe2bb78dc269c127806<Response [200]>
# PATCH/ID: 664e3fe25e09fcb997231e6c<Response [200]>
# PATCH/ID: 664e3f65dfd1445da967afcd<Response [200]>
# PATCH/ID: 664e3fe26dbb89b2920e00f7<Response [200]>
# PATCH/ID: 664e3fe35ac19415c3fced0d<Response [200]>
# PATCH/ID: 664e3fe36dbb8976e00e00f8<Response [200]>
# PATCH/ID: 664e3fe35ac19465dafced0e<Response [200]>
# PATCH/ID: 664e3fe3dfd1443dbc67afe5<Response [200]>
# PATCH/ID: 664e3fe35e09fc8233231e6d<Response [200]>
# PATCH/ID: 664e3fe481d36cab083c813b<Response [200]>
# PATCH/ID: 664e3fe4bb78dc3401127807<Response [200]>
# PATCH/ID: 664e3f66f770ceab88f295fd<Response [200]>
# PATCH/ID: 664e3fe519a6b033c53c6999<Response [200]>
# PATCH/ID: 664e3fe46451d03ff2859029<Response [200]>
# PATCH/ID: 664e3fe432e1df722d9ab2c4<Response [200]>
# PATCH/ID: 664e3fe55ac194642efced0f<Response [200]>
# PATCH/ID: 664e3fe532e1df4ab49ab2c5<Response [200]>
# PATCH/ID: 664e3fe519a6b07af53c699a<Response [200]>
# PATCH/ID: 664e3fe581c6a33e8acfb93c<Response [200]>
# PATCH/ID: 664e3fe65ac1948563fced10<Response [200]>
# PATCH/ID: 664e3f6581d36c78d63c811b<Response [200]>
# PATCH/ID: 664e3fe64434546a54c92e1b<Response [200]>
# PATCH/ID: 664e3fe6dfd1449af567afe6<Response [200]>
# PATCH/ID: 664e3fe75ac1943e27fced11<Response [200]>
# PATCH/ID: 664e3fe76451d0868185902a<Response [200]>
# PATCH/ID: 664e3f66f770cecfe0f295fe<Response [200]>
# PATCH/ID: 664e3fe75ac194398afced12<Response [200]>
# PATCH/ID: 664e3fe719a6b014943c699b<Response [200]>
# PATCH/ID: 664e3fe76dbb89097c0e00f9<Response [200]>
# PATCH/ID: 664e3fe8f770ce3a15f29617<Response [200]>
# PATCH/ID: 664e3fe86dbb8939970e00fa<Response [200]>
# PATCH/ID: 664e3fe8a13908b38c26710a<Response [200]>
# PATCH/ID: 664e3fe86dbb892a4a0e00fb<Response [200]>
# PATCH/ID: 664e3fe832e1df07a39ab2c6<Response [200]>
# PATCH/ID: 664e3fe9e434ef199d68f5ed<Response [200]>
# PATCH/ID: 664e3fe96dbb893d500e00fc<Response [200]>
# PATCH/ID: 664e3fe95e09fcfd64231e6e<Response [200]>
# PATCH/ID: 664e3fea5ac194791afced13<Response [200]>
# PATCH/ID: 664e3fe9443454f1e1c92e1c<Response [200]>
# PATCH/ID: 664e3fea5ac1943b0efced14<Response [200]>
# PATCH/ID: 664e3fea4ccee06ce276cb89<Response [200]>
# PATCH/ID: 664e3fea81c6a3407acfb93d<Response [200]>
# PATCH/ID: 664e3f6681c6a37d19cfb91e<Response [200]>
# PATCH/ID: 664e3feb32e1df63299ab2c7<Response [200]>
# PATCH/ID: 664e3feb19a6b04b273c699c<Response [200]>
# PATCH/ID: 664e3feb5ac1944b05fced15<Response [200]>
# PATCH/ID: 664e3f665e09fcc830231e55<Response [200]>
# PATCH/ID: 664e3feb81c6a31a03cfb93e<Response [200]>
# PATCH/ID: 664e3fec6451d0481f85902b<Response [200]>
# PATCH/ID: 664e3fecf770ceff89f29618<Response [200]>
# PATCH/ID: 664e3fecf770ce44b0f29619<Response [200]>
# PATCH/ID: 664e3fece434ef064f68f5ee<Response [200]>
# PATCH/ID: 664e3fec5ac194a994fced16<Response [200]>
# PATCH/ID: 664e3f675e09fc59d7231e56<Response [200]>
# PATCH/ID: 664e3feddfd144c24c67afe7<Response [200]>
# PATCH/ID: 664e3fed5e09fc863d231e6f<Response [200]>
# PATCH/ID: 664e3feda13908382f26710b<Response [200]>
# PATCH/ID: 664e3fed81c6a3a6d0cfb93f<Response [200]>
# PATCH/ID: 664e3fed32e1df597e9ab2c8<Response [200]>
# PATCH/ID: 664e3fee6dbb89cd870e00fd<Response [200]>
# PATCH/ID: 664e3fee6dbb89d4fd0e00fe<Response [200]>
# PATCH/ID: 664e3feebb78dcc66d127808<Response [200]>
# PATCH/ID: 664e3fee5e09fc8eb3231e70<Response [200]>
# PATCH/ID: 664e3fee5ac194206dfced17<Response [200]>
# PATCH/ID: 664e3fef4ccee0235c76cb8a<Response [200]>
# Script Finalizado
