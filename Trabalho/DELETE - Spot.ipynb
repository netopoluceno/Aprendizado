# %%
# MARCELO HENRIQUE MARTINELLI MARTINS - 24/05/2023
# Este código deleta SPOTS de uma lista de IDs
# INPUT: excel.xlsx (coluna: Spot_id)

#-------------

#LOGIN

import requests
import pandas as pd
import json
import jwt
import time
import getpass
from datetime import datetime

class PredictAPIClient():
    
    def __init__(self, email, password, project ='production'):
       self.email = email
       self.password = password
       self.token=''

       if project =='production':
            self.firebase_key = 'AIzaSyB2YzH6Vxj021oj1Prcdd8V-jpwUtbERMU'
            url_base = 'https://predict.dynamox.solutions'  
            self.psa_address = f'{url_base}/psa/v4'
            self.pra_address = f'{url_base}/pra/v4'
            self.public_key = '-----BEGINCERTIFICATE-----...-----ENDCERTIFICATE-----'
       
       elif project =='sandbox':
            self.firebase_key = 'AIzaSyCbgUaYoVbBUTy3RN2rJrfhmvdZW5G5f7k'
            url_base = 'https://sandbox.predict.dynamox.solutions'           
            self.psa_address = f'{url_base}/psa/v4'
            self.pra_address = f'{url_base}/pra/v4'
            self.public_key = '-----BEGINCERTIFICATE-----...-----ENDCERTIFICATE-----'
            
       elif project =='local':
            self.firebase_key = 'AIzaSyCbgUaYoVbBUTy3RN2rJrfhmvdZW5G5f7k'
            url_base = 'http://localhost'           
            self.psa_address = f'{url_base}:8080'
            self.pra_address = f'{url_base}:3003'
            self.public_key = '-----BEGINCERTIFICATE-----...-----ENDCERTIFICATE-----'

       else:
            url_base = []
            print('Connection problems, project name is incorrect!')
       self.login()

    def login(self):
            login_url = f'https://identitytoolkit.googleapis.com/v1/accounts:signInWithPassword?key={self.firebase_key}'
            self.login_data = {'email': self.email, 
                              'password': self.password,
                              'returnSecureToken': True}

            header = {'cache-control': 'no-cache',
                     'content-type': 'application/json',
                     'userAgent': 'Dyna-tools'}

            r = requests.post(login_url, data=json.dumps(self.login_data), headers=header)

            if r.status_code == 200:
               self.token = r.json()['idToken']
               print(f'Hello {email}')
            else:
               print(f'Connection problem getting measurements. HTTP Status Codes: {r.status_code}')
        
    def verify_token(self,token):
        decoded = jwt.JWT().decode(token, None, False)
        now = datetime.now().timestamp()
        exp = decoded.get("exp")
        diff = exp-now
        
        if diff < 300:
            print(f'Token expired, refreshing...')
            self.login()
            
email = 'edvaldo.neto@dynamox.net'
project = 'production'
password = getpass.getpass('Digite a senha: ')
api = PredictAPIClient(email, password, project)
# Out:
# Digite a senha: ········
# Hello edvaldo.neto@dynamox.net

# %%
#RODAR O DELETE

headers = {"Authorization": f"Bearer {api.token}"}

Spot_list = pd.read_excel(r'C:\Users\edvaldo.neto\Desktop\spots_alunorte_matheus.xlsx', sheet_name='delete_spots')
Spot_list = list (Spot_list['ids'])

for id in Spot_list:
    r = requests.delete((f"https://predict.dynamox.solutions/psa/v4/spots/{id}?version=3.23.0&client=predict-webapp"), headers=headers)
    print(id, "/", r.status_code)
    
print("Script Finalizado")
# Out:
# 6570734264184e754c8f3a98 / 200
# 657073461f2ec94f35ac891f / 200
# 6570734a1f2ec93a58ac8968 / 200
# 6570734e60f8e2176a7ab2e1 / 200
# 657074c84759e90ec3a7a6e6 / 200
# 657074cb60f8e281687b8286 / 200
# 657074c0b495a2aab2f2849d / 200
# 657074c44759e9d013a7a666 / 200
# 657074d74759e97987a7aad4 / 200
# 657074cf479b489d60947deb / 200
# 657074d34759e935c2a7aa93 / 200
# 6570743e64184eae768fda51 / 200
# 657074411f2ec92652ace744 / 200
# 6570743660f8e2957a7b68da / 200
# 6570743a1f2ec9d4f4ace707 / 200
# 6570744d1f2ec9c17face82e / 200
# 65707451479b485300946be7 / 200
# 65707445b495a2c399f25a55 / 200
# 6570744960f8e26b387b6a73 / 200
# 657073bb60f8e2cafa7b5502 / 200
# 657073bf64184e6d218fcb0f / 200
# 657073c2dedf4b42c24a48e0 / 200
# 657073c61f2ec91b94accb67 / 200
# 657073ca64184e7bcb8fcb2d / 200
# 657073ceb62c9469ce25eff8 / 200
# 657073d2dedf4bce654a4abb / 200
# 657073d5b62c94733625f0b9 / 200
# 657073d90affa58f21c46b4a / 200
# 657073dd60f8e2ca187b5a63 / 200
# 657073e11f2ec91b11acd5dc / 200
# 657073e5b62c9434e325f6b4 / 200
# 657073e964184e7b6a8fd27a / 200
# 657073ee0affa563bbc46f7e / 200
# 657073f1dedf4be76e4a5a96 / 200
# 657073f5479b4845d694598c / 200
# 657073f9479b485000945995 / 200
# 657073fd60f8e24c077b6121 / 200
# 657074011f2ec92062ace1a7 / 200
# 6570740464184e33c88fd4d7 / 200
# 657074081f2ec94edcace228 / 200
# 6570740c4759e9829ca7936d / 200
# 657074101f2ec967bface291 / 200
# 65707414b62c94cf2426046a / 200
# 657074e760f8e22a377b86de / 200
# 657074eb479b487940948404 / 200
# 657074dfa0a5b4956654af5c / 200
# 657074e3b495a2330ef28ac3 / 200
# 657074f760f8e22b8a7b8a44 / 200
# 657074fb479b48533b948600 / 200
# 657074ef0affa53dcbc49003 / 200
# 657074f3479b489d6394854d / 200
# 6570745c64184e67b28fddbf / 200
# 6570746064184e80cc8fde01 / 200
# 6570745564184e0ce58fdc1c / 200
# 65707458b62c9449ea2614ab / 200
# 6570746b64184ecb9d8fdf26 / 200
# 6570746fdedf4b595d4a64bb / 200
# 6570746360f8e2269a7b6e2c / 200
# 65707468dedf4b28d74a64ba / 200
# 65707333479b48185a93d603 / 200
# 657073374759e98687a772b4 / 200
# 6570733b64184e5b748f3a57 / 200
# 6570733f0affa5374fc4314f / 200
# 657073514759e911e3a773ef / 200
# 657073551f2ec9277dac9426 / 200
# 6570735960f8e2c4d07ab370 / 200
# 6570735d1f2ec9799cac9505 / 200
# 657074a9b495a213eff27c62 / 200
# 657074ad479b48316c947a6c / 200
# 657074a160f8e253a57b7669 / 200
# 657074a5479b48011c947988 / 200
# 657074b91f2ec9499facfa04 / 200
# 657074bcb62c947e692621e0 / 200
# 657074b1a0a5b4373454aa29 / 200
# 657074b5479b484bda947ae8 / 200
# 6570736164184e7d538f3d83 / 200
# 65707364b62c94fa5f25e501 / 200
# 65707368b495a20412f20712 / 200
# 6570736c479b48153d93dc36 / 200
# 65707370dedf4b4e314a3d61 / 200
# 657073740affa5863ec4359d / 200
# 6570737860f8e236b47ab9ce / 200
# 6570737ca0a5b44a6b542eb5 / 200
# 6570747a1f2ec967a2acf2c5 / 200
# 6570747e60f8e2c0807b6f12 / 200
# 65707473dedf4b0d9b4a64bc / 200
# 657074761f2ec96d2bacf245 / 200
# 6570748ab495a2d200f27832 / 200
# 6570748e60f8e27f597b6f42 / 200
# 657074820affa5b43fc47eb5 / 200
# 65707485b62c941a0d261798 / 200
# 6570749ab62c94c8c4261db8 / 200
# 6570749e0affa56067c4840d / 200
# 65707492b62c94c487261868 / 200
# 65707496479b48576d947845 / 200
# 65707380dedf4b6db94a3f16 / 200
# 6570738564184e02d48fc383 / 200
# 6570738aa0a5b4a938542f68 / 200
# 6570738ededf4ba3954a40e5 / 200
# 6570739a60f8e224f87b528f / 200
# 657073a01f2ec97b97acc6fd / 200
# 657073a464184e5e838fc74a / 200
# 657073a84759e9efb3a78020 / 200
# 657073acb62c94041425ec9e / 200
# 657073b064184ed5218fc9e2 / 200
# 657073b31f2ec95c55acc921 / 200
# 657073b74759e98534a781b7 / 200
# 6570742ededf4b42fa4a612d / 200
# 65707432dedf4b29bc4a612e / 200
# 65707427b495a24e98f2596f / 200
# 6570742a60f8e262c67b6835 / 200
# 6570741fdedf4b78b44a5fbc / 200
# 65707423a0a5b4470154969d / 200
# 65707417a0a5b46f2a549268 / 200
# 6570741b64184ef4228fd709 / 200
# Script Finalizado
